# %%
import pandas as pd
import numpy as np

# %%
file_path = 'abc.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
tmp = df.index.tolist()

# %%
new_df = pd.DataFrame(tmp)

# %%
new_df.head()
# Out:
#                       0         1         2         3         4         5     \
# 0                 ScanTime  189.8800  190.2600  190.6500  191.0300  191.4200
# 1  2014-03-28 14:56:21.598  589.8150  589.8150  589.8150  475.1288  409.5938
# 2  2014-03-28 14:56:21.698  484.4909  484.4909  484.4909  425.9775  437.6802
# 3  2014-03-28 14:56:21.798  531.3016  531.3016  531.3016  418.9559  360.4425
# 4  2014-03-28 14:56:21.898  526.6205  526.6205  526.6205  514.9178  421.2964
#
#        6         7         8         9     ...      2038      2039      2040  \
# 0  191.8000  192.1900  192.5700  192.9600  ...  889.8600  890.1500  890.4500
# 1  383.8479  470.4477  390.8695  381.5073  ...  575.7718  599.1771  599.1771
# 2  421.2964  381.5073  430.6586  404.9127  ...  585.1339  554.7070  608.5393
# 3  414.2748  449.3828  444.7018  416.6154  ...  589.8150  620.2419  573.4313
# 4  475.1288  461.0855  351.0804  379.1668  ...  540.6638  554.7070  582.7934
#
# ...

# %%
new_df_index = [tmp[i][0] for i in range(1, df.shape[0])]
new_df_index
# Out:
# ['2014-03-28 14:56:21.598',
#  '2014-03-28 14:56:21.698',
#  '2014-03-28 14:56:21.798',
#  '2014-03-28 14:56:21.898',
#  '2014-03-28 14:56:21.998',
#  '2014-03-28 14:56:22.098',
#  '2014-03-28 14:56:22.198',
#  '2014-03-28 14:56:22.298',
#  '2014-03-28 14:56:22.398',
#  '2014-03-28 14:56:22.498',
#  '2014-03-28 14:56:22.598',
#  '2014-03-28 14:56:22.698',
#  '2014-03-28 14:56:22.798',
#  '2014-03-28 14:56:22.898',
#  '2014-03-28 14:56:22.998',
#  '2014-03-28 14:56:23.098',
#  '2014-03-28 14:56:23.198',
#  '2014-03-28 14:56:23.298',
#  '2014-03-28 14:56:23.398',
#  '2014-03-28 14:56:23.498',
#  '2014-03-28 14:56:23.598',
#  '2014-03-28 14:56:23.698',
#  '2014-03-28 14:56:23.799',
#  '2014-03-28 14:56:23.899',
#  '2014-03-28 14:56:23.999',
#  '2014-03-28 14:56:24.099',
#  '2014-03-28 14:56:24.199',
#  '2014-03-28 14:56:24.299',
#  '2014-03-28 14:56:24.399',
#  '2014-03-28 14:56:24.499',
#  '2014-03-28 14:56:24.599',
#  '2014-03-28 14:56:24.699',
#  '2014-03-28 14:56:24.799',
# ...

# %%
new_df_columns_name = list(tmp[0][1:])
new_df_columns_name
# Out:
# [189.88,
#  190.26,
#  190.65,
#  191.03,
#  191.42,
#  191.8,
#  192.19,
#  192.57,
#  192.96,
#  193.34,
#  193.73,
#  194.11,
#  194.5,
#  194.88,
#  195.27,
#  195.65,
#  196.04,
#  196.42,
#  196.81,
#  197.19,
#  197.57,
#  197.96,
#  198.34,
#  198.73,
#  199.11,
#  199.5,
#  199.88,
#  200.26,
#  200.65,
#  201.03,
#  201.42,
#  201.8,
#  202.19,
#  202.57,
#  202.95,
#  203.34,
#  203.72,
#  204.11,
#  204.49,
#  204.87,
#  205.26,
#  205.64,
#  206.02,
#  206.41,
#  206.79,
#  207.18,
#  207.56,
#  207.94,
#  208.33,
#  208.71,
#  209.09,
#  209.48,
#  209.86,
#  210.24,
#  210.63,
#  211.01,
#  211.39,
#  211.78,
#  212.16,
#  212.54,
#  212.93,
#  213.31,
#  213.69,
#  214.08,
#  214.46,
#  214.84,
#  215.22,
#  215.61,
#  215.99,
#  216.37,
#  216.76,
#  217.14,
#  217.52,
#  217.9,
#  218.29,
#  218.67,
#  219.05,
#  219.43,
#  219.82,
#  220.2,
#  220.58,
#  220.96,
#  221.35,
#  221.73,
#  222.11,
#  222.49,
#  222.88,
#  223.26,
#  223.64,
#  224.02,
#  224.4,
# ...

# %%
new_df = pd.DataFrame([[tmp[i][j] for j in range(1, len(new_df_columns_name))] for i in range(1, len(new_df_index))])

# %%
new_df.shape
# Out:
# (609, 2047)

# %%
new_df.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  589.8150  589.8150  589.8150  475.1288  409.5938  383.8479  470.4477
# 1  484.4909  484.4909  484.4909  425.9775  437.6802  421.2964  381.5073
# 2  531.3016  531.3016  531.3016  418.9559  360.4425  414.2748  449.3828
# 3  526.6205  526.6205  526.6205  514.9178  421.2964  475.1288  461.0855
# 4  507.8962  507.8962  507.8962  519.5989  411.9343  456.4044  425.9775
#
#        7         8         9     ...      2037      2038      2039      2040  \
# 0  390.8695  381.5073  367.4641  ...  575.7718  599.1771  599.1771  610.8798
# 1  430.6586  404.9127  430.6586  ...  585.1339  554.7070  608.5393  554.7070
# 2  444.7018  416.6154  423.6370  ...  589.8150  620.2419  573.4313  634.2852
# 3  351.0804  379.1668  397.8911  ...  540.6638  554.7070  582.7934  603.8582
# 4  404.9127  402.5721  369.8047  ...  587.4745  557.0475  601.5177  543.0043
#
#        2041      2042      2043      2044      2045      2046
# ...

# %%
new_df.index = new_df_index
new_df.columns = new_df_columns_name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [122], in <cell line: 2>()
#       1 new_df.index = new_df_index
# ----> 2 new_df.columns = new_df_columns_name
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
# ...
